# %% [markdown]
# ## Machine Learning Assignment 2 Solutions
#
#
# ### 1.	What is the concept of human learning? Please give two examples.
#
# Human learning is the process of learning new knowledge, behaviour, skills, etc.
#
# For ex: When a child runs how to walk, when a human study new things at school.
#
# ### 2.	What different forms of human learning are there? Are there any machine learning equivalents?
#
# - Artificial Intelligence Learning Theories. Machine Learning. Reinforcement Learning. Supervised Learning. Unsupervised Learning.
# - ML equivalents like Linear regression, decision trees, random forest and support vector machines are some commonly used techniques that are actually examples of supervised learning.
#
#
# ### 3. What is machine learning, and how does it work? What are the key responsibilities of machine learning?
#
# Machine learning is a part of Artifical Intelligance and it basically learns from the data given and predict the future or improve performance.
#
# It works by identifying patterns, learning about them, etc
#
# Key reponsibilitys:
# - Removing outliers
# - test the model after creation it
# - getting better result
#
# ### 4. Define the terms "penalty" and "reward" in the context of reinforcement learning.
#
# Reinforcement learning can be referred as Agent. When agent does good work he given reward else penalty. Therefore, agent will maximize production and get max rewards and minimize penalty
#
# ### 5. Explain the term "learning as a search"?
#
# It is a search through the concept description which describes the sentence best
#
# ### 6. What are the various goals of machine learning? What is the relationship between these and human learning?
#
# Goals of ml are to analysis patterns in the data and give or predict the best possible result, also help's in solving the problems
#
# The relation b/w ml and human learning is that human learns from experience or shared by someone and ml learns from the past data provided to it.
#
# ### 7. Illustrate the various elements of machine learning using a real-life illustration.
#
# - Data
# - Model
# - Loss Function
# - Learning Algorithm
# - Evaluation
# - Maintenance
#
# ### 8. Provide an example of the abstraction method.
#
# class A():
#
#     def a(self):
#         pass
#
# class B(A):
#
#     def a(self):
#         print('here')
#
# B().a()
#
# ### 9. What is the concept of generalization? What function does it play in the machine learning process?
#
# Generalization refers to your model's ability to adapt properly to new, previously unseen data, drawn from the same distribution as the one used to create the model.
#
# In machine learning, generalization is a definition to demonstrate how well is a trained model to classify or forecast unseen data.This issue can result to classify an actual dog image as a cat from the unseen dataset. Therefore, data diversity is very important factor in order to make a good prediction.
#
# ### 10. What is classification, exactly? What are the main distinctions between classification and regression?
#
# Classification is supervised machine learning and it predicts the categorial/discrete output only while regression predicts the result in continous.
#
# ### 11. What is regression, and how does it work? Give an example of a real-world problem that was solved using regression.
#
# Regression is a Supervised machine learning and it predicts the continuous output. There are 3 main metrics for regression, variance, error and bias.
#
# Real world ex:
# - Predicting the value of house
# - Stock market prediction
#
# ### 12. Describe the clustering mechanism in detail.
#
# Cluster mecahnism is when the population data is divided into groups and those groups are created based on nearer to the data points. So, data points closer to one another will form 1 group and other will form another group.
